# %% [markdown]
# ### 4.3.6 folium을 이용한 지도 시각화 1 - 개별표시

# %%
import pandas as pd
location_data = pd.read_excel('./files/location_inform.xlsx')
location_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name_official  97 non-null     object
#  1   경도             97 non-null     float64
#  2   위도             97 non-null     float64
#  3   인스타위치명         97 non-null     object
#  4   place          97 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 3.9+ KB

# %%
location_data
# Out:
#    name_official          경도         위도            인스타위치명  place
# 0          유우스테이  126.754239  33.557782             유우스테이     57
# 1          제주육대표  126.490104  33.494012             제주육대표     15
# 2        월정리해수욕장  126.795805  33.556469             월정리해변      2
# 3        월정리해수욕장  126.795805  33.556469  Woljeongri Beach      2
# 4        월정리해수욕장  126.795805  33.556469           월정리해수욕장      2
# ..           ...         ...        ...               ...    ...
# 92           모찌롱  126.509368  33.507160               모찌롱      1
# 93        애월해안도로  126.368679  33.478123            애월해안도로      1
# 94         전망대횟집  126.260957  33.423083             전망대횟집      1
# 95          종달부부  126.908169  33.496023              종달부부      1
# 96           무공간  126.797288  33.554146               무공간      1
#
# [97 rows x 5 columns]

# %%
# !pip install folium
import folium
# Out:
# Collecting folium
#   Downloading folium-0.11.0-py2.py3-none-any.whl (93 kB)
# Requirement already satisfied: numpy in c:\users\jye12\anaconda\lib\site-packages (from folium) (1.19.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in c:\users\jye12\anaconda\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\jye12\anaconda\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jye12\anaconda\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jye12\anaconda\lib\site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jye12\anaconda\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jye12\anaconda\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jye12\anaconda\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0

# %%
Mt_Hanla = [33.362500, 126.556394]

map_jeju = folium.Map(location = Mt_Hanla, zoom_start =11)
for i in range(len(location_data)):
    name = location_data['name_official'][i]
    count = location_data['place'][i]
    size = int(count) *2
    long = float(location_data['위도'][i])
    lat = float(location_data['경도'][i])
    folium.CircleMarker((long,lat) , radius=size, color= 'red' , popup =name).add_to(map_jeju)

map_jeju
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
