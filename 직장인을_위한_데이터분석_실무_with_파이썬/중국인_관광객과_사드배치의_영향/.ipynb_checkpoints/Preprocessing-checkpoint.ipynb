# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 3.1 외국인 출입국 통계 데이터 구하기
# 한국관광공사
# http://kto.visitkorea.or.kr/kor/notice/data/statics/tstat/profit/notice/inout/popup.kto

# %% [markdown]
# # 3.2 데이터 불러오기 및 전처리

# %% [markdown]
# ### 3.2.1 불러올 데이터의 형태 파악

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. 첫 번째 로우에는 해당 파일 데이터가 어느 시점의 어떤 종류의 데이터인지 서술돼 있습니다.
#    데이터 분석에는 활용하지 않는항목이므로 데이터를 불러올 때 제외해야 합니다.
#
# 2. 두 번째 로우에는 총 10개의 칼럼이 순서대로 나열돼 있습니다.
#    10개의 칼럼에 대해 데이터분석에 활용할 칼럼들을 검토할 필요가 있습니다. 이번 예제에서는 A칼럼에서 G칼럼까지 총 7개의 칼럼을 활용하겠습니다.
#
# 3. 3~69로우에는 대륙, 국가에 따른 관광객 수 데이터가 구성돼 있습니다.
#    실제로 데이터 분석에 활용할 항목입니다.
#
# 4. 70~73번째 로우에는 계,전년 동기, 성장률(%), 구성비(%) 등 데이터의 요약 정보로 구성돼 있습니다.
#    1번 항목과 마찬가지로 데이터 분석에 활용하지 않는 항목이므로 데이터를 불러올 때 제외해야 합니다.

# %% [markdown]
# ### 3.2.2 파이썬에서 엑셀 데이터 불러오기

# %%
kto_201901 = pd.read_excel('./files/kto_201901.xlsx',
                          header =1 ,  # 두 번째 줄에 변수명이 있는 것을 의미
                          usecols = 'A:G', # A~G 칼럼을 사용
                          skipfooter = 4 ) # 밑에 4줄은 생략
kto_201901.head()
# Out:
#      국적      관광     상용    공용  유학/연수      기타       계
# 0  아시아주  765082  10837  1423  14087  125521  916950
# 1    일본  198805   2233   127    785    4576  206526
# 2    대만   86393     74    22    180    1285   87954
# 3    홍콩   34653     59     2     90    1092   35896
# 4   마카오    2506      2     0     17      45    2570

# %%
kto_201901.tail()
# Out:
#          국적   관광   상용  공용  유학/연수     기타      계
# 62  아프리카 기타  768  718  90    206    908   2690
# 63     기타대륙   33    4   0      1     16     54
# 64     국적미상   33    4   0      1     16     54
# 65     교포소계    0    0   0      0  15526  15526
# 66       교포    0    0   0      0  15526  15526

# %% [markdown]
# ### 3.2.3 데이터 전처리
# - 분석에 적합한 형태로 가공하는 것
# - 이상치, 결측값 확인, 이상치 처리, 변수 정규화, 파생변수 생성 등의 과정

# %%
kto_201901.info() # 해당 데이터 분야에 대한 도메인 지식 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
condition = (kto_201901['관광'] == 0) \
            | (kto_201901['상용'] == 0)\
            | (kto_201901['공용'] == 0)\
            | (kto_201901['유학/연수'] == 0)  # 각 칼럼에서 0인 부분을 필터링 
kto_201901[condition]
# Out:
#         국적    관광   상용  공용  유학/연수     기타      계
# 4      마카오  2506    2   0     17     45   2570
# 20    이스라엘   727   12   0      9     57    805
# 22  우즈베키스탄  1958  561   0    407   2828   5754
# 38     스위스   613   18   0     19     97    747
# 45     그리스   481   17   4      0    273    775
# 46    포르투갈   416   14   0     13    121    564
# 51   크로아티아   226   12   0      3    250    491
# 54     폴란드   713   10   0     27    574   1324
# 59  대양주 기타   555    3   4      0     52    614
# 63    기타대륙    33    4   0      1     16     54
# 64    국적미상    33    4   0      1     16     54
# 65    교포소계     0    0   0      0  15526  15526
# 66      교포     0    0   0      0  15526  15526

# %% [markdown]
# #### *데이터프레임에 기준년월 추가*

# %%
kto_201901['기준년월'] = '2019-01'
kto_201901.head()
# Out:
#      국적      관광     상용    공용  유학/연수      기타       계     기준년월
# 0  아시아주  765082  10837  1423  14087  125521  916950  2019-01
# 1    일본  198805   2233   127    785    4576  206526  2019-01
# 2    대만   86393     74    22    180    1285   87954  2019-01
# 3    홍콩   34653     59     2     90    1092   35896  2019-01
# 4   마카오    2506      2     0     17      45    2570  2019-01

# %% [markdown]
# #### *국적 데이터만 남기기*

# %%
kto_201901['국적'].unique() # 칼럼내 중복을 제거한 값들을 보여줌
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %%
continents_list = ['아시아주', '미주','구주', '대양주', '아프리카주',  '기타대륙', '교포소계']
continents_list
# Out:
# ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']

# %%
condition = (kto_201901.국적.isin(continents_list) == False)  # continents_list 에 없는 것만 
kto_201901_country = kto_201901[condition]
kto_201901_country['국적'].unique()
# Out:
# array(['일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아', '싱가포르',
#        '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골', '중국',
#        '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미국',
#        '캐나다', '멕시코', '브라질', '미주 기타', '영국', '독일', '프랑스', '네덜란드', '스웨덴',
#        '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인', '그리스', '포르투갈',
#        '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아', '불가리아', '폴란드',
#        '구주 기타', '오스트레일리아', '뉴질랜드', '대양주 기타', '남아프리카공화국', '아프리카 기타',
#        '국적미상', '교포'], dtype=object)

# %%
kto_201901_country.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월
# 1   일본  198805  2233  127    785  4576  206526  2019-01
# 2   대만   86393    74   22    180  1285   87954  2019-01
# 3   홍콩   34653    59    2     90  1092   35896  2019-01
# 4  마카오    2506     2    0     17    45    2570  2019-01
# 5   태국   34004    37  199     96  6998   41334  2019-01

# %%
kto_201901_country_newindex = kto_201901_country.reset_index(drop =True)
kto_201901_country_newindex
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월
# 0         일본  198805  2233   127    785   4576  206526  2019-01
# 1         대만   86393    74    22    180   1285   87954  2019-01
# 2         홍콩   34653    59     2     90   1092   35896  2019-01
# 3        마카오    2506     2     0     17     45    2570  2019-01
# 4         태국   34004    37   199     96   6998   41334  2019-01
# 5      말레이시아   19043    95     7     99   2821   22065  2019-01
# 6        필리핀   14279   211   161    184  15638   30473  2019-01
# 7      인도네시아   14183   136    38    187   4298   18842  2019-01
# 8       싱가포르    8372    94     8     48   1333    9855  2019-01
# 9        미얀마    1304    10    31     67   3877    5289  2019-01
# 10       베트남   10739   763   110   1667   6904   20183  2019-01
# 11        인도    2318  2656    46    177   3474    8671  2019-01
# 12      스리랑카     157    54     5     28   1043    1287  2019-01
# 13      파키스탄     238   178    10    193    413    1032  2019-01
# ...

# %% [markdown]
# #### *대륙 칼럼 생성*

# %%
continents = ['아시아'] *25 + ['아메리카'] * 5 +['유럽'] * 23 + ['오세아니아'] *3 + ['아프리카'] * 2 + ['기타대륙'] + ['교포']
print(continents)
# Out:
# ['아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아메리카', '아메리카', '아메리카', '아메리카', '아메리카', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '오세아니아', '오세아니아', '오세아니아', '아프리카', '아프리카', '기타대륙', '교포']

# %%
kto_201901_country_newindex['대륙'] = continents
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아

# %%
kto_201901_country_newindex.tail()
# Out:
#           국적   관광   상용  공용  유학/연수     기타      계     기준년월     대륙
# 55    대양주 기타  555    3   4      0     52    614  2019-01  오세아니아
# 56  남아프리카공화국  368    9   1      6    616   1000  2019-01   아프리카
# 57   아프리카 기타  768  718  90    206    908   2690  2019-01   아프리카
# 58      국적미상   33    4   0      1     16     54  2019-01   기타대륙
# 59        교포    0    0   0      0  15526  15526  2019-01     교포

# %% [markdown]
# #### *국적별 관광객 비율 살펴보기*

# %%
kto_201901_country_newindex['관광객비율(%)'] = \
    round(kto_201901_country_newindex['관광']  / kto_201901_country_newindex['계'] * 100, 1)
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아      96.3
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아      98.2
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아      96.5
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아      97.5
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아      82.3

# %%
kto_201901_country_newindex.sort_values(by= '관광객비율(%)', ascending =False).head()
# Out:
#         국적      관광    상용   공용  유학/연수    기타       계     기준년월     대륙  관광객비율(%)
# 1       대만   86393    74   22    180  1285   87954  2019-01    아시아      98.2
# 3      마카오    2506     2    0     17    45    2570  2019-01    아시아      97.5
# 2       홍콩   34653    59    2     90  1092   35896  2019-01    아시아      96.5
# 0       일본  198805  2233  127    785  4576  206526  2019-01    아시아      96.3
# 55  대양주 기타     555     3    4      0    52     614  2019-01  오세아니아      90.4

# %%
kto_201901_country_newindex.pivot_table(values = '관광객비율(%)', index = '대륙',aggfunc ='mean')
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   61.100000
# 아메리카   68.200000
# 아시아    59.624000
# 아프리카   32.700000
# 오세아니아  84.833333
# 유럽     63.826087

# %%
condition = (kto_201901_country_newindex.국적 == '중국')
kto_201901_country_newindex[condition]
# Out:
#     국적      관광    상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)
# 17  중국  320113  2993  138   8793  60777  392814  2019-01  아시아      81.5

# %%
tourist_sum = sum(kto_201901_country_newindex.관광)
tourist_sum
# Out:
# 884293

# %%
kto_201901_country_newindex['전체비율(%)'] = round(kto_201901_country_newindex.관광 / tourist_sum *100 ,1)
kto_201901_country_newindex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아      96.3
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아      98.2
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아      96.5
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아      97.5
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아      82.3
#
#    전체비율(%)
# 0     22.5
# 1      9.8
# 2      3.9
# 3      0.3
# 4      3.8

# %%
kto_201901_country_newindex.sort_values('전체비율(%)', ascending=False).head()
# Out:
#     국적      관광    상용    공용  유학/연수     기타       계     기준년월    대륙  관광객비율(%)  \
# 17  중국  320113  2993   138   8793  60777  392814  2019-01   아시아      81.5
# 0   일본  198805  2233   127    785   4576  206526  2019-01   아시아      96.3
# 1   대만   86393    74    22    180   1285   87954  2019-01   아시아      98.2
# 25  미국   42989   418  2578    229  16523   62737  2019-01  아메리카      68.5
# 2   홍콩   34653    59     2     90   1092   35896  2019-01   아시아      96.5
#
#     전체비율(%)
# 17     36.2
# 0      22.5
# 1       9.8
# 25      4.9
# 2       3.9

# %% [markdown]
# #### 3.2.4 데이터 전처리 과정을 함수로 만들기

# %%
def create_kto_data(yy,mm):
    # 불러올 엑셀 파일 경로 지정
    file_path = './files/kto_{}{}.xlsx'.format(yy,mm)
    
    # 엑셀 파일 불러오기
    df = pd.read_excel(file_path, header=1 ,skipfooter = 4, usecols= 'A:G')
    
    # '기준년월' 칼럼 추가
    df['기준년월'] = '{}-{}'.format(yy,mm)
    
    # "국적" 칼럼에서 대륙 제거하고 국가만 남기기
    continents_list = ['아시아주', '미주','구주', '대양주', '아프리카주',  '기타대륙', '교포소계']
    condition = (df['국적'].isin(continents_list) == False)
    df_country = df[condition].reset_index(drop=True)
    
    #'대륙' 칼럼 추가
    continents = ['아시아'] *25 + ['아메리카'] * 5 +['유럽'] * 23 + ['오세아니아'] *3 + ['아프리카'] * 2 + ['기타대륙'] + ['교포']
    df_country['대륙'] = continents
    
    # 국가별 "관광객비율(%)" 칼럼 추가
    df_country['관광객비율(%)'] = round(df_country.관광 / df_country.계 * 100 ,1 )
    
    # 전체비율(%) 칼럼 추가
    tourist_sum = sum(df_country['관광'])
    df_country['전체비율(%)'] = round(df_country['관광'] / tourist_sum * 100 ,1)
    
    return(df_country)

# %% [markdown]
# #### 3.2.5 반복문을 통해 다수의 엑셀 데이터를 불러와서 합치기

# %%
for yy in range(2010,2020):
    for mm in range(1,13):
        yymm= '{}{}'.format(yy,mm)
        print(yymm)
# Out:
# 20101
# 20102
# 20103
# 20104
# 20105
# 20106
# 20107
# 20108
# 20109
# 201010
# 201011
# 201012
# 20111
# 20112
# 20113
# 20114
# 20115
# 20116
# 20117
# 20118
# 20119
# 201110
# 201111
# 201112
# 20121
# 20122
# 20123
# 20124
# 20125
# 20126
# 20127
# 20128
# 20129
# 201210
# 201211
# 201212
# 20131
# 20132
# 20133
# 20134
# 20135
# 20136
# 20137
# 20138
# 20139
# 201310
# 201311
# 201312
# 20141
# 20142
# 20143
# 20144
# 20145
# 20146
# 20147
# 20148
# 20149
# 201410
# 201411
# 201412
# 20151
# 20152
# 20153
# 20154
# 20155
# 20156
# 20157
# 20158
# 20159
# 201510
# 201511
# 201512
# 20161
# 20162
# 20163
# 20164
# 20165
# 20166
# 20167
# 20168
# 20169
# 201610
# 201611
# 201612
# 20171
# 20172
# 20173
# 20174
# 20175
# 20176
# 20177
# 20178
# 20179
# 201710
# 201711
# 201712
# 20181
# 20182
# 20183
# 20184
# 20185
# 20186
# 20187
# 20188
# 20189
# 201810
# 201811
# 201812
# 20191
# 20192
# 20193
# 20194
# 20195
# 20196
# 20197
# 20198
# 20199
# 201910
# 201911
# 201912

# %%
for yy in range(2010,2020):
    for mm in range(1,13):
        mm_str =str(mm).zfill(2)
        yymm= '{}{}'.format(yy,mm_str)
        print(yymm)
# Out:
# 201001
# 201002
# 201003
# 201004
# 201005
# 201006
# 201007
# 201008
# 201009
# 201010
# 201011
# 201012
# 201101
# 201102
# 201103
# 201104
# 201105
# 201106
# 201107
# 201108
# 201109
# 201110
# 201111
# 201112
# 201201
# 201202
# 201203
# 201204
# 201205
# 201206
# 201207
# 201208
# 201209
# 201210
# 201211
# 201212
# 201301
# 201302
# 201303
# 201304
# 201305
# 201306
# 201307
# 201308
# 201309
# 201310
# 201311
# 201312
# 201401
# 201402
# 201403
# 201404
# 201405
# 201406
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# ...

# %%
df = pd.DataFrame()
for yy in range(2010,2020):
    for mm in range(1,13):
        temp = create_kto_data(str(yy),str(mm).zfill(2))
        df = df.append(temp,ignore_index = True)

# %%
df
# Out:
#             국적      관광    상용  공용  유학/연수    기타       계     기준년월     대륙  \
# 0           일본  202825  1750  89    549  3971  209184  2010-01    아시아
# 1           대만   35788    41  17     37   516   36399  2010-01    아시아
# 2           홍콩   13874    55   0     21   595   14545  2010-01    아시아
# 3          마카오     554     0   0      0     0     554  2010-01    아시아
# 4           태국   13374    39  13     53  4335   17814  2010-01    아시아
# ...        ...     ...   ...  ..    ...   ...     ...      ...    ...
# 7195    대양주 기타     154     2   4      0    92     252  2019-12  오세아니아
# 7196  남아프리카공화국     665     3   0      3   251     922  2019-12   아프리카
# 7197   아프리카 기타    1273   644  66     93  1002    3078  2019-12   아프리카
# 7198      국적미상      36     1   0      0    10      47  2019-12   기타대륙
# 7199        교포       0     0   0      0  5281    5281  2019-12     교포
#
#       관광객비율(%)  전체비율(%)
# 0         97.0     50.6
# 1         98.3      8.9
# 2         95.4      3.5
# 3        100.0      0.1
# ...
