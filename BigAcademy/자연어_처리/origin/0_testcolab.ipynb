# %% [markdown]
# # 구글 드라이브와 파일 불러오기

# %%
# 실행 확인
print("hi")

# %%
# 구글 드라이브와 연결하기
# from google.colab import auth
# auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')

# %%
# 폴더 확인
# 명령에는 !를 사용한다 (경로 변경에는 %)
# !ls "/content/gdrive/My Drive/"

# %%
# 구글 드라이브에 있는 파일 읽기
import pandas as pd
df = pd.read_csv("/content/gdrive/My Drive/pytest/test.csv", encoding="euc-kr")   # cp949, euc-kr / utf-8
print(df)

# %%
# encoding을 파이썬 코드로 확인하는 방법
# !pip install chardet
import chardet

file = open("/content/gdrive/My Drive/pytest/test.csv", "rb").read()
result = chardet.detect(file)
print(result['encoding'])
